# %%
import os
import re

# %%
# Out:
# ; Peptoid versions of the canonical amino acids
#
#
#
# [ ALAp ] ; peptoid version of alanine (sarcosine)
#
#   [ atoms ]
#
#            NL   NH1   -0.210  0
#
#            CB   CT3   -0.270  1
#
#           HB1   HA3    0.090  2
#
#           HB2   HA3    0.090  3
#
#           HB3   HA3    0.090  4
#
#            CA   CT2    0.030  5
#
#           HA1   HB2    0.090  6
#
#           HA2   HB2    0.090  7
#
#           CLP    TC    0.510  8
#
#            OL     O   -0.510  9
#
#   [ bonds ]
#
#           -CLP  NL
#
#             NL  CB
#
#             CB  HB1
#
#             CB  HB2
#
#             CB  HB3
#
#             NL   CA
#
#             CA  HA1
#
#             CA  HA2
#
#             CA  CLP
#
#            CLP   OL
#
#            CLP  +NL
#
#   [ impropers ]
#
#             NL  -CLP    CA   CB
#
#             CLP   CA    +NL  OL
#
#
#
# [ ARGp ] ; peptoid residue original arginine
#
#   [ atoms ]
#
#            NL   NH1   -0.210  0
#
#            CB   CT2   -0.180  1
#
# ...
